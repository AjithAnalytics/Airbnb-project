# %%
#install pymongo
# !python -m pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.6.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.4.2)

# %%
#import necessary packages
import pandas as pd
import numpy as np
import datetime as dt
import os
pd.pandas.set_option('display.max_columns',None)

# %%
#connection establishment
import pymongo
from pymongo.mongo_client import MongoClient
client = MongoClient(f"mongodb+srv://farmerajith:Sandy@cluster0.xb14cgk.mongodb.net/?retryWrites=true&w=majority")
db = client['sample_airbnb']
collection = db['listingsAndReviews']

# %%
#Extract data from mongoDB
rel_data = []
for i in collection.find():
    data = dict(Id = i['_id'],
                Listing_url = i['listing_url'],
                Name = i.get('name'),
                space = i['space'],
                Description = i['description'],
                neighborhood_overview = i['neighborhood_overview'],
                notes = i['notes'],
                transit = i['transit'],
                access = i['access'],
                interaction = i['interaction'],
                House_rules = i.get('house_rules'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Minimum_nights = i['minimum_nights'],
                Maximum_nights = i['maximum_nights'],
                Cancellation_policy = i['cancellation_policy'],
                last_scraped = i['last_scraped'],
                calendar_last_scraped = i[ 'calendar_last_scraped'],
                first_review = i.get('first_review'),
                last_review = i.get('last_review'),
                Accomodates = i['accommodates'],
                bedrooms = i.get('bedrooms'),
                beds = i.get('beds'),
                number_of_reviews = i['number_of_reviews'],
                bathrooms = i.get('bathrooms'),
                Amenities = ', '.join(i['amenities']),
                Price = i['price'],
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                images_picture_url = i['images']['picture_url'],
                host_id = i['host']['host_id'],
                host_url = i['host']['host_url'],
                host_name = i['host']['host_name'],
                host_location =i['host']['host_location'],
                host_about = i['host']['host_about'],
                host_response_time = i.get('host', {}).get('host_response_time'),
                host_thumbnail_url = i['host']['host_thumbnail_url'],
                host_picture_url = i['host']['host_picture_url'],
                host_neighbourhood = i['host']['host_neighbourhood'],
                host_response_rate = i.get('host', {}).get('host_response_rate'),
                host_is_superhost = i['host']['host_is_superhost'],
                host_has_profile_pic = i['host']['host_has_profile_pic'],
                host_identity_verified = i['host']['host_identity_verified'],
                host_listings_count = i['host']['host_listings_count'],
                host_total_listings_count = i['host']['host_total_listings_count'],
                host_verifications = i['host']['host_verifications'],
                Street = i['address']['street'],
                Suburb = i['address']['suburb'],
                Government_Area = i['address']['government_area'],
                Market = i['address']['market'],
                Country = i['address']['country'],
                Country_Code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_Location_Exact = i['address']['location']['is_location_exact'],
                review_scores_accuracy = i['review_scores'].get('review_scores_accuracy'),
                review_scores_cleanliness = i['review_scores'].get('review_scores_cleanliness'),
                review_scores_checkin = i['review_scores'].get('review_scores_checkin'),
                review_scores_communication = i['review_scores'].get('review_scores_communication'),
                review_scores_location = i['review_scores'].get('review_scores_location'),
                review_scores_value = i['review_scores'].get('review_scores_value'),
                review_scores_rating = i['review_scores'].get('review_scores_rating'),
                availability_30 = i['availability'].get('availability_30'),
                availability_60 = i['availability'].get('availability_60'),
                availability_90= i['availability'].get('availability_90'),
                availability_365= i['availability'].get('availability_365')
    )
    rel_data.append(data)
data=pd.DataFrame(rel_data)
data.head()
# Out:
#          Id                            Listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                Name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Lovely one bedroom + sofa-bed in the living ro...
# 2  Great studio located on Ala Moana across the s...
# 3
# 4
#
#                                          Description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  A short distance from Honolulu's billion dolla...
# 3  Here exists a very cozy room for rent in a sha...
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1  This charming ground floor flat is located in ...
# 2             You can breath ocean as well as aloha.
# 3
# 4
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
# 1  There´s a table in the living room now, that d...
# 2
# 3
# 4
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
# 1  Easy access to transport (bus, taxi, car) and ...
# 2  Honolulu does have a very good air conditioned...
# 3
# 4
#
#                                               access  \
# 0  We are always available to help guests. The ho...
# 1
# 2                           Pool, hot tub and tennis
# 3
# 4
#
#                                          interaction  \
# 0             Cot - 10 € / night Dog - € 7,5 / night
# 1  I´ll be happy to help you with any doubts, tip...
# 2  We try our best at creating, simple responsive...
# 3
# 4
#
#                                          House_rules Property_type  \
# 0                        Make the house your home...         House
# 1  I just hope the guests treat the space as they...     Apartment
# 2  The general welfare and well being of all the ...   Condominium
# 3                                                        Apartment
# 4                                                        Apartment
#
#          Room_type  Bed_type Minimum_nights Maximum_nights  \
# 0  Entire home/apt  Real Bed              2             30
# 1  Entire home/apt  Real Bed              2           1125
# 2  Entire home/apt  Real Bed              3            365
# 3     Private room  Real Bed             14           1125
# 4     Private room  Real Bed              1           1125
#
#            Cancellation_policy        last_scraped calendar_last_scraped  \
# 0                     moderate 2019-02-16 05:00:00   2019-02-16 05:00:00
# 1                     flexible 2019-02-11 05:00:00   2019-02-11 05:00:00
# 2  strict_14_with_grace_period 2019-03-06 05:00:00   2019-03-06 05:00:00
# 3                     flexible 2019-03-06 05:00:00   2019-03-06 05:00:00
# 4                     flexible 2019-02-11 05:00:00   2019-02-11 05:00:00
#
#          first_review         last_review  Accomodates  bedrooms  beds  \
# 0 2016-01-03 05:00:00 2019-01-20 05:00:00            8       3.0   5.0
# 1                 NaT                 NaT            4       1.0   2.0
# 2 2013-05-24 04:00:00 2019-02-07 05:00:00            2       1.0   1.0
# 3 2016-01-31 05:00:00 2016-01-31 05:00:00            1       1.0   1.0
# 4                 NaT                 NaT            2       1.0   1.0
#
#    number_of_reviews bathrooms  \
# 0                 51       1.0
# 1                  0       1.0
# 2                 96       1.0
# 3                  1       1.5
# 4                  0       2.0
#
#                                            Amenities   Price Extra_people  \
# 0  TV, Cable TV, Wifi, Kitchen, Paid parking off ...   80.00        15.00
# 1  Wifi, Wheelchair accessible, Kitchen, Free par...  317.00         0.00
# 2  TV, Cable TV, Wifi, Air conditioning, Pool, Ki...  115.00         0.00
# 3  Internet, Wifi, Air conditioning, Kitchen, Buz...   40.00         0.00
# 4  TV, Cable TV, Internet, Wifi, Air conditioning...  701.00         0.00
#
#   Guests_included                                 images_picture_url  \
# 0               6  https://a0.muscache.com/im/pictures/e83e702f-e...
# 1               1  https://a0.muscache.com/im/pictures/5b408b9e-4...
# 2               1  https://a0.muscache.com/im/pictures/15037101/5...
# 3               1  https://a0.muscache.com/im/pictures/72844c8c-f...
# 4               1  https://a0.muscache.com/im/pictures/59c516bd-c...
#
#     host_id                                    host_url    host_name  \
# 0  51399391  https://www.airbnb.com/users/show/51399391  Ana&Gonçalo
# 1   1282196   https://www.airbnb.com/users/show/1282196        Ynaie
# 2   5448114   https://www.airbnb.com/users/show/5448114        David
# 3  11275734  https://www.airbnb.com/users/show/11275734         Josh
# 4  51496939  https://www.airbnb.com/users/show/51496939        Livia
#
#                                      host_location  \
# 0                  Porto, Porto District, Portugal
# 1  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2                  Honolulu, Hawaii, United States
# 3                New York, New York, United States
# 4                                               BR
#
#                                           host_about host_response_time  \
# 0  Gostamos de passear, de viajar, de conhecer pe...     within an hour
# 1  I am an artist and traveling is a major part o...               None
# 2  I have 30 years of experience in the Waikiki R...     within an hour
# 3                                                                  None
# 4                                                                  None
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 2  https://a0.muscache.com/im/users/5448114/profi...
# 3  https://a0.muscache.com/im/users/11275734/prof...
# 4  https://a0.muscache.com/im/pictures/b7911710-9...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/pictures/9681e3cc-4...    Jardim Botânico
# 2  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 3  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 4  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
#
#    host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0               100.0              False                  True
# 1                 NaN              False                  True
# 2                98.0              False                  True
# 3                 NaN              False                  True
# 4                 NaN              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    True                    3                          3
# 1                   False                    1                          1
# 2                   False                   18                         18
# 3                    True                    1                          1
# 4                   False                    1                          1
#
#                                   host_verifications  \
# 0  [email, phone, reviews, jumio, offline_governm...
# 1                           [email, phone, facebook]
# 2                       [email, phone, reviews, kba]
# 3                       [email, phone, reviews, kba]
# 4               [email, phone, jumio, government_id]
#
#                                    Street           Suburb  \
# 0                  Porto, Porto, Portugal
# 1  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2             Honolulu, HI, United States            Oʻahu
# 3             Brooklyn, NY, United States         Brooklyn
# 4  Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
#
#                                      Government_Area          Market  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 1                                    Jardim Botânico  Rio De Janeiro
# 2                               Primary Urban Center            Oahu
# 3                                           Bushwick        New York
# 4                                              Lagoa  Rio De Janeiro
#
#          Country Country_Code Location_type   Longitude   Latitude  \
# 0       Portugal           PT         Point   -8.613080  41.141300
# 1         Brazil           BR         Point  -43.230750 -22.966254
# 2  United States           US         Point -157.839190  21.286340
# 3  United States           US         Point  -73.936150  40.697910
# 4         Brazil           BR         Point  -43.205047 -22.971951
#
#    Is_Location_Exact  review_scores_accuracy  review_scores_cleanliness  \
# 0              False                     9.0                        9.0
# 1               True                     NaN                        NaN
# 2               True                     9.0                        8.0
# 3               True                    10.0                       10.0
# 4               True                     NaN                        NaN
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                    NaN                          NaN                     NaN
# 2                    9.0                          9.0                    10.0
# 3                   10.0                         10.0                     8.0
# 4                    NaN                          NaN                     NaN
#
#    review_scores_value  review_scores_rating  availability_30  \
# 0                  9.0                  89.0               28
# 1                  NaN                   NaN                0
# 2                  9.0                  84.0               16
# 3                  8.0                 100.0                0
# 4                  NaN                   NaN               28
#
#    availability_60  availability_90  availability_365
# 0               47               74               239
# 1                0                0                 0
# 2               46               76               343
# 3                0                0                 0
# 4               58               88               363

# %%
data.shape
# Out:
# (5555, 68)

# %%
data.columns
# Out:
# Index(['Id', 'Listing_url', 'Name', 'space', 'Description',
#        'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
#        'House_rules', 'Property_type', 'Room_type', 'Bed_type',
#        'Minimum_nights', 'Maximum_nights', 'Cancellation_policy',
#        'last_scraped', 'calendar_last_scraped', 'first_review', 'last_review',
#        'Accomodates', 'bedrooms', 'beds', 'number_of_reviews', 'bathrooms',
#        'Amenities', 'Price', 'Extra_people', 'Guests_included',
#        'images_picture_url', 'host_id', 'host_url', 'host_name',
#        'host_location', 'host_about', 'host_response_time',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_response_rate', 'host_is_superhost', 'host_has_profile_pic',
#        'host_identity_verified', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications', 'Street', 'Suburb',
#        'Government_Area', 'Market', 'Country', 'Country_Code', 'Location_type',
#        'Longitude', 'Latitude', 'Is_Location_Exact', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'review_scores_rating', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 68 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           5555 non-null   object
#  1   Listing_url                  5555 non-null   object
#  2   Name                         5555 non-null   object
#  3   space                        5555 non-null   object
#  4   Description                  5555 non-null   object
#  5   neighborhood_overview        5555 non-null   object
#  6   notes                        5555 non-null   object
#  7   transit                      5555 non-null   object
#  8   access                       5555 non-null   object
#  9   interaction                  5555 non-null   object
#  10  House_rules                  5555 non-null   object
#  11  Property_type                5555 non-null   object
#  12  Room_type                    5555 non-null   object
#  13  Bed_type                     5555 non-null   object
#  14  Minimum_nights               5555 non-null   object
#  15  Maximum_nights               5555 non-null   object
#  16  Cancellation_policy          5555 non-null   object
#  17  last_scraped                 5555 non-null   datetime64[ns]
#  18  calendar_last_scraped        5555 non-null   datetime64[ns]
#  19  first_review                 4167 non-null   datetime64[ns]
#  20  last_review                  4167 non-null   datetime64[ns]
#  21  Accomodates                  5555 non-null   int64
#  22  bedrooms                     5550 non-null   float64
#  23  beds                         5542 non-null   float64
#  24  number_of_reviews            5555 non-null   int64
#  25  bathrooms                    5545 non-null   object
#  26  Amenities                    5555 non-null   object
#  27  Price                        5555 non-null   object
#  28  Extra_people                 5555 non-null   object
#  29  Guests_included              5555 non-null   object
#  30  images_picture_url           5555 non-null   object
#  31  host_id                      5555 non-null   object
#  32  host_url                     5555 non-null   object
#  33  host_name                    5555 non-null   object
#  34  host_location                5555 non-null   object
#  35  host_about                   5555 non-null   object
#  36  host_response_time           4167 non-null   object
#  37  host_thumbnail_url           5555 non-null   object
#  38  host_picture_url             5555 non-null   object
#  39  host_neighbourhood           5555 non-null   object
#  40  host_response_rate           4167 non-null   float64
#  41  host_is_superhost            5555 non-null   bool
#  42  host_has_profile_pic         5555 non-null   bool
#  43  host_identity_verified       5555 non-null   bool
#  44  host_listings_count          5555 non-null   int64
#  45  host_total_listings_count    5555 non-null   int64
#  46  host_verifications           5555 non-null   object
#  47  Street                       5555 non-null   object
#  48  Suburb                       5555 non-null   object
#  49  Government_Area              5555 non-null   object
#  50  Market                       5555 non-null   object
#  51  Country                      5555 non-null   object
#  52  Country_Code                 5555 non-null   object
#  53  Location_type                5555 non-null   object
#  54  Longitude                    5555 non-null   float64
#  55  Latitude                     5555 non-null   float64
#  56  Is_Location_Exact            5555 non-null   bool
#  57  review_scores_accuracy       4079 non-null   float64
#  58  review_scores_cleanliness    4082 non-null   float64
#  59  review_scores_checkin        4080 non-null   float64
#  60  review_scores_communication  4081 non-null   float64
#  61  review_scores_location       4081 non-null   float64
#  62  review_scores_value          4080 non-null   float64
#  63  review_scores_rating         4081 non-null   float64
#  64  availability_30              5555 non-null   int64
#  65  availability_60              5555 non-null   int64
#  66  availability_90              5555 non-null   int64
#  67  availability_365             5555 non-null   int64
# dtypes: bool(4), datetime64[ns](4), float64(12), int64(8), object(40)
# memory usage: 2.7+ MB

# %%
#check nall values columns only
feature_with_nan=[i for i in data.columns if data[i].isnull().sum()>=1]
feature_with_nan
# Out:
# ['first_review',
#  'last_review',
#  'bedrooms',
#  'beds',
#  'bathrooms',
#  'host_response_time',
#  'host_response_rate',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'review_scores_rating']

# %%
#filter missing values in %
for i in feature_with_nan:
  print(i,np.round(data[i].isnull().mean()*100, 5),"% of missing values")
# Out:
# first_review 24.9865 % of missing values
# last_review 24.9865 % of missing values
# bedrooms 0.09001 % of missing values
# beds 0.23402 % of missing values
# bathrooms 0.18002 % of missing values
# host_response_time 24.9865 % of missing values
# host_response_rate 24.9865 % of missing values
# review_scores_accuracy 26.57066 % of missing values
# review_scores_cleanliness 26.51665 % of missing values
# review_scores_checkin 26.55266 % of missing values
# review_scores_communication 26.53465 % of missing values
# review_scores_location 26.53465 % of missing values
# review_scores_value 26.55266 % of missing values
# review_scores_rating 26.53465 % of missing values

# %%
 # missing data handling
data['beds'].fillna(0, axis=0, inplace = True)
data['bedrooms'].fillna(0, axis=0, inplace = True)
data['bathrooms'].fillna(0, axis=0, inplace = True)
#data['last_review'].fillna('0',axis=0,inplace = True)
#data['first_review'].fillna('0',axis=0,inplace = True)

# %%
# integer
data['Id'] = data['Id'].astype(int)
data['host_id'] = data['host_id'].astype(int)
data['Minimum_nights'] = data['Minimum_nights'].astype(int)
data['Maximum_nights'] = data['Maximum_nights'].astype(int)
data['Accomodates'] = data['Accomodates'].astype(int)
data['bedrooms'] = data['bedrooms'].astype(int)
data['beds'] = data['beds'].astype(int)
data['number_of_reviews'] = data['number_of_reviews'].astype(int)

# %%
#float
data['bathrooms'] = data['bathrooms'].astype(str).astype(float)
data[ 'Price'] = data[ 'Price'].astype(str).astype(float)
data[ 'Extra_people'] = data[ 'Extra_people'].astype(str).astype(float)
data[ 'Guests_included'] = data[ 'Guests_included'].astype(str).astype(float)

# %%
# datetime
data['last_scraped'] = pd.to_datetime(data['last_scraped'], format = '%Y-%m-%d').dt.date
data['calendar_last_scraped'] = pd.to_datetime(data['calendar_last_scraped'], format = '%Y-%m-%d').dt.date
#data['first_review'] = pd.to_datetime(data['first_review'], format = '%Y-%m-%d').dt.date
# Assuming 'first_review' is the column you want to convert to datetime
data['first_review'] = pd.to_datetime(data['first_review'], errors='coerce', format='%Y-%m-%d')
default_date = pd.to_datetime('1970-01-01')
data['first_review'].fillna(default_date, inplace=True)
data['first_review'] = data['first_review'].dt.date

#data['last_review'] = pd.to_datetime(data['last_review'], format = '%Y-%m-%d').dt.date
data['last_review'] = pd.to_datetime(data['last_review'], errors='coerce', format='%Y-%m-%d')
default_date = pd.to_datetime('1970-01-01')
data['last_review'].fillna(default_date, inplace=True)
data['last_review'] = data['last_review'].dt.date

# %%
def Preprocessing(data):

    duplicates = data.duplicated(subset = 'Id', keep = 'first')
    if not duplicates.empty:
        data.drop(data[duplicates].index, inplace = True)

    inconsistent_days=data[(data['availability_30'] < 0 ) & (data['availability_30'] >30)]
    if not inconsistent_days.empty:
        data.drop(inconsistent_days.index, inplace = True)

    inconsistent_days=data[(data['availability_60'] <0 ) & (data['availability_60'] >60)]
    if not inconsistent_days.empty:
        data.drop(inconsistent_days.index, inplace = True)

    inconsistent_days=data[(data['availability_90'] <0 ) & (data['availability_90'] >90)]
    if not inconsistent_days.empty:
        data.drop(inconsistent_days.index, inplace = True)

    inconsistent_days=data[(data['availability_365'] <0 ) & (data['availability_365'] >365)]
    if not inconsistent_days.empty:
        data.drop(inconsistent_days.index, inplace = True)

    inconsistent_dates = data[(data['last_review'] > dt.date.today()) | (data['first_review']> dt.date.today())]
    if not inconsistent_dates.empty:
        data.drop(inconsistent_dates.index, inplace = True)

    inconsistent_dates = data[data['first_review'] > data['last_review']]
    if not inconsistent_dates.empty:
        data.drop(inconsistent_dates.index, inplace = True)

    is_host_response = np.where((data['host_response_time'].isna() == True) & (data['host_response_rate'].isna() == True), 0, 1)
    if len(is_host_response):
        data['is_host_response'] = is_host_response

        data = data.fillna({'host_response_time':0,
                                'host_response_rate':0})

    is_review_scores = np.where((data['review_scores_accuracy'].isna() == True) & (data['review_scores_cleanliness'].isna() == True) &
                                (data['review_scores_checkin'].isna() == True) & (data['review_scores_communication'].isna() == True) &
                                (data['review_scores_location'].isna() == True) & (data['review_scores_value'].isna() == True) &
                                (data['review_scores_rating'].isna() == True)
                                , 0, 1)

    if len(is_review_scores):
        data['is_review_scores'] = is_review_scores

        data= data.fillna({'review_scores_accuracy':0,
                                'review_scores_cleanliness':0,
                                'review_scores_checkin':0,
                                'review_scores_communication':0,
                                'review_scores_location':0,
                                'review_scores_value':0,
                                'review_scores_rating':0,})

    return data

# %%
data=Preprocessing(data)
data.head()
# Out:
#          Id                            Listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                Name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Lovely one bedroom + sofa-bed in the living ro...
# 2  Great studio located on Ala Moana across the s...
# 3
# 4
#
#                                          Description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  A short distance from Honolulu's billion dolla...
# 3  Here exists a very cozy room for rent in a sha...
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1  This charming ground floor flat is located in ...
# 2             You can breath ocean as well as aloha.
# 3
# 4
#
#                                                notes  \
# 0  Lose yourself in the narrow streets and stairc...
# 1  There´s a table in the living room now, that d...
# 2
# 3
# 4
#
#                                              transit  \
# 0  Transport: • Metro station and S. Bento railwa...
# 1  Easy access to transport (bus, taxi, car) and ...
# 2  Honolulu does have a very good air conditioned...
# 3
# 4
#
#                                               access  \
# 0  We are always available to help guests. The ho...
# 1
# 2                           Pool, hot tub and tennis
# 3
# 4
#
#                                          interaction  \
# 0             Cot - 10 € / night Dog - € 7,5 / night
# 1  I´ll be happy to help you with any doubts, tip...
# 2  We try our best at creating, simple responsive...
# 3
# 4
#
#                                          House_rules Property_type  \
# 0                        Make the house your home...         House
# 1  I just hope the guests treat the space as they...     Apartment
# 2  The general welfare and well being of all the ...   Condominium
# 3                                                        Apartment
# 4                                                        Apartment
#
#          Room_type  Bed_type  Minimum_nights  Maximum_nights  \
# 0  Entire home/apt  Real Bed               2              30
# 1  Entire home/apt  Real Bed               2            1125
# 2  Entire home/apt  Real Bed               3             365
# 3     Private room  Real Bed              14            1125
# 4     Private room  Real Bed               1            1125
#
#            Cancellation_policy last_scraped calendar_last_scraped  \
# 0                     moderate   2019-02-16            2019-02-16
# 1                     flexible   2019-02-11            2019-02-11
# 2  strict_14_with_grace_period   2019-03-06            2019-03-06
# 3                     flexible   2019-03-06            2019-03-06
# 4                     flexible   2019-02-11            2019-02-11
#
#   first_review last_review  Accomodates  bedrooms  beds  number_of_reviews  \
# 0   2016-01-03  2019-01-20            8         3     5                 51
# 1   1970-01-01  1970-01-01            4         1     2                  0
# 2   2013-05-24  2019-02-07            2         1     1                 96
# 3   2016-01-31  2016-01-31            1         1     1                  1
# 4   1970-01-01  1970-01-01            2         1     1                  0
#
#    bathrooms                                          Amenities  Price  \
# 0        1.0  TV, Cable TV, Wifi, Kitchen, Paid parking off ...   80.0
# 1        1.0  Wifi, Wheelchair accessible, Kitchen, Free par...  317.0
# 2        1.0  TV, Cable TV, Wifi, Air conditioning, Pool, Ki...  115.0
# 3        1.5  Internet, Wifi, Air conditioning, Kitchen, Buz...   40.0
# 4        2.0  TV, Cable TV, Internet, Wifi, Air conditioning...  701.0
#
#    Extra_people  Guests_included  \
# 0          15.0              6.0
# 1           0.0              1.0
# 2           0.0              1.0
# 3           0.0              1.0
# 4           0.0              1.0
#
#                                   images_picture_url   host_id  \
# 0  https://a0.muscache.com/im/pictures/e83e702f-e...  51399391
# 1  https://a0.muscache.com/im/pictures/5b408b9e-4...   1282196
# 2  https://a0.muscache.com/im/pictures/15037101/5...   5448114
# 3  https://a0.muscache.com/im/pictures/72844c8c-f...  11275734
# 4  https://a0.muscache.com/im/pictures/59c516bd-c...  51496939
#
#                                      host_url    host_name  \
# 0  https://www.airbnb.com/users/show/51399391  Ana&Gonçalo
# 1   https://www.airbnb.com/users/show/1282196        Ynaie
# 2   https://www.airbnb.com/users/show/5448114        David
# 3  https://www.airbnb.com/users/show/11275734         Josh
# 4  https://www.airbnb.com/users/show/51496939        Livia
#
#                                      host_location  \
# 0                  Porto, Porto District, Portugal
# 1  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 2                  Honolulu, Hawaii, United States
# 3                New York, New York, United States
# 4                                               BR
#
#                                           host_about host_response_time  \
# 0  Gostamos de passear, de viajar, de conhecer pe...     within an hour
# 1  I am an artist and traveling is a major part o...                  0
# 2  I have 30 years of experience in the Waikiki R...     within an hour
# 3                                                                     0
# 4                                                                     0
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/pictures/9681e3cc-4...
# 2  https://a0.muscache.com/im/users/5448114/profi...
# 3  https://a0.muscache.com/im/users/11275734/prof...
# 4  https://a0.muscache.com/im/pictures/b7911710-9...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fab79f25-2...
# 1  https://a0.muscache.com/im/pictures/9681e3cc-4...    Jardim Botânico
# 2  https://a0.muscache.com/im/users/5448114/profi...            Waikiki
# 3  https://a0.muscache.com/im/users/11275734/prof...           Bushwick
# 4  https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
#
#    host_response_rate  host_is_superhost  host_has_profile_pic  \
# 0               100.0              False                  True
# 1                 0.0              False                  True
# 2                98.0              False                  True
# 3                 0.0              False                  True
# 4                 0.0              False                  True
#
#    host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                    True                    3                          3
# 1                   False                    1                          1
# 2                   False                   18                         18
# 3                    True                    1                          1
# 4                   False                    1                          1
#
#                                   host_verifications  \
# 0  [email, phone, reviews, jumio, offline_governm...
# 1                           [email, phone, facebook]
# 2                       [email, phone, reviews, kba]
# 3                       [email, phone, reviews, kba]
# 4               [email, phone, jumio, government_id]
#
#                                    Street           Suburb  \
# 0                  Porto, Porto, Portugal
# 1  Rio de Janeiro, Rio de Janeiro, Brazil  Jardim Botânico
# 2             Honolulu, HI, United States            Oʻahu
# 3             Brooklyn, NY, United States         Brooklyn
# 4  Rio de Janeiro, Rio de Janeiro, Brazil            Lagoa
#
#                                      Government_Area          Market  \
# 0  Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...           Porto
# 1                                    Jardim Botânico  Rio De Janeiro
# 2                               Primary Urban Center            Oahu
# 3                                           Bushwick        New York
# 4                                              Lagoa  Rio De Janeiro
#
#          Country Country_Code Location_type   Longitude   Latitude  \
# 0       Portugal           PT         Point   -8.613080  41.141300
# 1         Brazil           BR         Point  -43.230750 -22.966254
# 2  United States           US         Point -157.839190  21.286340
# 3  United States           US         Point  -73.936150  40.697910
# 4         Brazil           BR         Point  -43.205047 -22.971951
#
#    Is_Location_Exact  review_scores_accuracy  review_scores_cleanliness  \
# 0              False                     9.0                        9.0
# 1               True                     0.0                        0.0
# 2               True                     9.0                        8.0
# 3               True                    10.0                       10.0
# 4               True                     0.0                        0.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                    10.0
# 1                    0.0                          0.0                     0.0
# 2                    9.0                          9.0                    10.0
# 3                   10.0                         10.0                     8.0
# 4                    0.0                          0.0                     0.0
#
#    review_scores_value  review_scores_rating  availability_30  \
# 0                  9.0                  89.0               28
# 1                  0.0                   0.0                0
# 2                  9.0                  84.0               16
# 3                  8.0                 100.0                0
# 4                  0.0                   0.0               28
#
#    availability_60  availability_90  availability_365  is_host_response  \
# 0               47               74               239                 1
# 1                0                0                 0                 0
# 2               46               76               343                 1
# 3                0                0                 0                 0
# 4               58               88               363                 0
#
#    is_review_scores
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 70 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Id                           5555 non-null   int64
#  1   Listing_url                  5555 non-null   object
#  2   Name                         5555 non-null   object
#  3   space                        5555 non-null   object
#  4   Description                  5555 non-null   object
#  5   neighborhood_overview        5555 non-null   object
#  6   notes                        5555 non-null   object
#  7   transit                      5555 non-null   object
#  8   access                       5555 non-null   object
#  9   interaction                  5555 non-null   object
#  10  House_rules                  5555 non-null   object
#  11  Property_type                5555 non-null   object
#  12  Room_type                    5555 non-null   object
#  13  Bed_type                     5555 non-null   object
#  14  Minimum_nights               5555 non-null   int64
#  15  Maximum_nights               5555 non-null   int64
#  16  Cancellation_policy          5555 non-null   object
#  17  last_scraped                 5555 non-null   object
#  18  calendar_last_scraped        5555 non-null   object
#  19  first_review                 5555 non-null   object
#  20  last_review                  5555 non-null   object
#  21  Accomodates                  5555 non-null   int64
#  22  bedrooms                     5555 non-null   int64
#  23  beds                         5555 non-null   int64
#  24  number_of_reviews            5555 non-null   int64
#  25  bathrooms                    5555 non-null   float64
#  26  Amenities                    5555 non-null   object
#  27  Price                        5555 non-null   float64
#  28  Extra_people                 5555 non-null   float64
#  29  Guests_included              5555 non-null   float64
#  30  images_picture_url           5555 non-null   object
#  31  host_id                      5555 non-null   int64
#  32  host_url                     5555 non-null   object
#  33  host_name                    5555 non-null   object
#  34  host_location                5555 non-null   object
#  35  host_about                   5555 non-null   object
#  36  host_response_time           5555 non-null   object
#  37  host_thumbnail_url           5555 non-null   object
#  38  host_picture_url             5555 non-null   object
#  39  host_neighbourhood           5555 non-null   object
#  40  host_response_rate           5555 non-null   float64
#  41  host_is_superhost            5555 non-null   bool
#  42  host_has_profile_pic         5555 non-null   bool
#  43  host_identity_verified       5555 non-null   bool
#  44  host_listings_count          5555 non-null   int64
#  45  host_total_listings_count    5555 non-null   int64
#  46  host_verifications           5555 non-null   object
#  47  Street                       5555 non-null   object
#  48  Suburb                       5555 non-null   object
#  49  Government_Area              5555 non-null   object
#  50  Market                       5555 non-null   object
#  51  Country                      5555 non-null   object
#  52  Country_Code                 5555 non-null   object
#  53  Location_type                5555 non-null   object
#  54  Longitude                    5555 non-null   float64
#  55  Latitude                     5555 non-null   float64
#  56  Is_Location_Exact            5555 non-null   bool
#  57  review_scores_accuracy       5555 non-null   float64
#  58  review_scores_cleanliness    5555 non-null   float64
#  59  review_scores_checkin        5555 non-null   float64
#  60  review_scores_communication  5555 non-null   float64
#  61  review_scores_location       5555 non-null   float64
#  62  review_scores_value          5555 non-null   float64
#  63  review_scores_rating         5555 non-null   float64
#  64  availability_30              5555 non-null   int64
#  65  availability_60              5555 non-null   int64
#  66  availability_90              5555 non-null   int64
#  67  availability_365             5555 non-null   int64
#  68  is_host_response             5555 non-null   int64
#  69  is_review_scores             5555 non-null   int64
# dtypes: bool(4), float64(14), int64(16), object(36)
# memory usage: 2.8+ MB

# %%
# Save DataFrame to CSV file
file_path = "Airbnbdataset.xlsx"
data.to_excel(file_path, index=False)
print(f"excel file saved at: {file_path}")
# Out:
# excel file saved at: Airbnbdataset.xlsx
